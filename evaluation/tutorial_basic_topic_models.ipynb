# %%
import os
os.chdir("C:/Users/1/Desktop/TopMost")
import topmost
from topmost.data import download_dataset

device = "cuda" # or "cpu"
dataset_dir = "./data/NYT"
dataset_name=dataset_dir.split("/")[-1]

# %%
########################### Neural Topic Models ####################################
# dataset for neural topic models.
# For combinedTM, add contextual_embed=True.1
# dataset = topmost.data.BasicDataset(dataset_dir, read_labels=True, device=device, pretrained_WE=True)
dataset = topmost.data.BasicDataset(dataset_dir, read_labels=True, device=device)
# Out:
# train_size:  8254
# test_size:  918
# vocab_size:  10000
# average length: 175.429

# %%
# create a model
# model = topmost.ProdLDA(dataset.vocab_size)
method = "ETM"
# model = topmost.ETM(dataset.vocab_size, pretrained_WE=dataset.pretrained_WE)
# model = topmost.DecTM(dataset.vocab_size)
# model = topmost.TSCTM(dataset.vocab_size)
# model = topmost.CombinedTM(dataset.vocab_size, dataset.contextual_embed_size)
# model = topmost.NSTM(dataset.vocab_size, pretrained_WE=dataset.pretrained_WE)
# model = topmost.ECRTM(dataset.vocab_size, pretrained_WE=dataset.pretrained_WE)

if method == "ETM":
    model = topmost.ETM(dataset.vocab_size, pretrained_WE=dataset.pretrained_WE)
elif method == "DecTM":
    model = topmost.DecTM(dataset.vocab_size)
elif method == "TSCTM":
    model = topmost.TSCTM(dataset.vocab_size)
elif method == "CombinedTM":
    model = topmost.CombinedTM(dataset.vocab_size, dataset.contextual_embed_size)
elif method == "NSTM":
    model = topmost.NSTM(dataset.vocab_size, pretrained_WE=dataset.pretrained_WE)
elif method == "ECRTM":
    model = topmost.ECRTM(dataset.vocab_size, pretrained_WE=dataset.pretrained_WE)
else:
    # 处理未定义的method情况
    raise ValueError(f"未支持的模型方法: {method}，请选择以下之一: ETM, DecTM, TSCTM, CombinedTM, NSTM, ECRTM")
    
model = model.to(device)

# create a trainer
trainer = topmost.BasicTrainer(model, dataset, verbose=True)

# train the model
top_words, train_theta = trainer.train()
# Out:
#   2%|▏         | 4/200 [00:01<01:01,  3.17it/s]2025-09-17 14:58:26,413 - TopMost - Epoch: 005 loss: 1673.157
#   4%|▍         | 9/200 [00:02<00:52,  3.61it/s]2025-09-17 14:58:27,731 - TopMost - Epoch: 010 loss: 1524.947
#   7%|▋         | 14/200 [00:04<00:51,  3.60it/s]2025-09-17 14:58:29,119 - TopMost - Epoch: 015 loss: 1471.543
#  10%|▉         | 19/200 [00:05<00:49,  3.65it/s]2025-09-17 14:58:30,480 - TopMost - Epoch: 020 loss: 1456.174
#  12%|█▏        | 24/200 [00:06<00:45,  3.91it/s]2025-09-17 14:58:31,781 - TopMost - Epoch: 025 loss: 1450.884
#  14%|█▍        | 29/200 [00:08<00:50,  3.40it/s]2025-09-17 14:58:33,160 - TopMost - Epoch: 030 loss: 1446.467
#  17%|█▋        | 34/200 [00:09<00:44,  3.70it/s]2025-09-17 14:58:34,570 - TopMost - Epoch: 035 loss: 1442.445
#  20%|█▉        | 39/200 [00:11<00:45,  3.53it/s]2025-09-17 14:58:36,096 - TopMost - Epoch: 040 loss: 1438.787
#  22%|██▏       | 44/200 [00:12<00:47,  3.26it/s]2025-09-17 14:58:37,592 - TopMost - Epoch: 045 loss: 1435.683
#  24%|██▍       | 49/200 [00:14<00:44,  3.41it/s]2025-09-17 14:58:39,089 - TopMost - Epoch: 050 loss: 1432.661
#  27%|██▋       | 54/200 [00:15<00:36,  3.97it/s]2025-09-17 14:58:40,379 - TopMost - Epoch: 055 loss: 1429.780
#  30%|██▉       | 59/200 [00:17<00:41,  3.41it/s]2025-09-17 14:58:41,922 - TopMost - Epoch: 060 loss: 1427.344
#  32%|███▏      | 64/200 [00:18<00:42,  3.19it/s]2025-09-17 14:58:43,476 - TopMost - Epoch: 065 loss: 1425.112
#  34%|███▍      | 69/200 [00:20<00:36,  3.56it/s]2025-09-17 14:58:44,984 - TopMost - Epoch: 070 loss: 1422.438
#  37%|███▋      | 74/200 [00:21<00:40,  3.15it/s]2025-09-17 14:58:46,609 - TopMost - Epoch: 075 loss: 1419.892
#  40%|███▉      | 79/200 [00:23<00:32,  3.68it/s]2025-09-17 14:58:47,953 - TopMost - Epoch: 080 loss: 1417.828
#  42%|████▏     | 84/200 [00:24<00:30,  3.76it/s]2025-09-17 14:58:49,297 - TopMost - Epoch: 085 loss: 1415.870
#  44%|████▍     | 89/200 [00:25<00:30,  3.61it/s]2025-09-17 14:58:50,798 - TopMost - Epoch: 090 loss: 1414.321
#  47%|████▋     | 94/200 [00:27<00:30,  3.48it/s]2025-09-17 14:58:52,202 - TopMost - Epoch: 095 loss: 1412.812
#  50%|████▉     | 99/200 [00:28<00:31,  3.23it/s]2025-09-17 14:58:53,825 - TopMost - Epoch: 100 loss: 1411.422
#  52%|█████▏    | 104/200 [00:30<00:26,  3.64it/s]2025-09-17 14:58:55,163 - TopMost - Epoch: 105 loss: 1410.030
#  55%|█████▍    | 109/200 [00:31<00:24,  3.76it/s]2025-09-17 14:58:56,543 - TopMost - Epoch: 110 loss: 1408.802
#  57%|█████▋    | 114/200 [00:33<00:26,  3.30it/s]2025-09-17 14:58:58,131 - TopMost - Epoch: 115 loss: 1407.826
#  60%|█████▉    | 119/200 [00:34<00:22,  3.57it/s]2025-09-17 14:58:59,487 - TopMost - Epoch: 120 loss: 1406.580
#  62%|██████▏   | 124/200 [00:36<00:21,  3.51it/s]2025-09-17 14:59:00,906 - TopMost - Epoch: 125 loss: 1405.562
#  64%|██████▍   | 129/200 [00:37<00:19,  3.73it/s]2025-09-17 14:59:02,262 - TopMost - Epoch: 130 loss: 1404.756
#  67%|██████▋   | 134/200 [00:38<00:19,  3.30it/s]2025-09-17 14:59:03,721 - TopMost - Epoch: 135 loss: 1404.019
#  70%|██████▉   | 139/200 [00:40<00:16,  3.78it/s]2025-09-17 14:59:05,030 - TopMost - Epoch: 140 loss: 1403.357
#  72%|███████▏  | 144/200 [00:41<00:16,  3.48it/s]2025-09-17 14:59:06,510 - TopMost - Epoch: 145 loss: 1402.846
#  74%|███████▍  | 149/200 [00:42<00:13,  3.77it/s]2025-09-17 14:59:07,812 - TopMost - Epoch: 150 loss: 1401.968
#  77%|███████▋  | 154/200 [00:44<00:11,  3.86it/s]2025-09-17 14:59:09,225 - TopMost - Epoch: 155 loss: 1401.211
#  80%|███████▉  | 159/200 [00:45<00:10,  3.82it/s]2025-09-17 14:59:10,537 - TopMost - Epoch: 160 loss: 1400.567
#  82%|████████▏ | 164/200 [00:47<00:12,  2.83it/s]2025-09-17 14:59:12,475 - TopMost - Epoch: 165 loss: 1400.163
#  84%|████████▍ | 169/200 [00:48<00:08,  3.69it/s]2025-09-17 14:59:14,064 - TopMost - Epoch: 170 loss: 1399.378
#  87%|████████▋ | 174/200 [00:50<00:08,  3.02it/s]2025-09-17 14:59:15,714 - TopMost - Epoch: 175 loss: 1398.934
#  90%|████████▉ | 179/200 [00:52<00:07,  2.69it/s]2025-09-17 14:59:17,617 - TopMost - Epoch: 180 loss: 1398.296
#  92%|█████████▏| 184/200 [00:54<00:06,  2.55it/s]2025-09-17 14:59:19,517 - TopMost - Epoch: 185 loss: 1397.670
#  94%|█████████▍| 189/200 [00:56<00:03,  2.82it/s]2025-09-17 14:59:21,396 - TopMost - Epoch: 190 loss: 1397.220
#  97%|█████████▋| 194/200 [00:57<00:01,  3.32it/s]2025-09-17 14:59:22,787 - TopMost - Epoch: 195 loss: 1396.791
# 100%|█████████▉| 199/200 [00:59<00:00,  3.68it/s]2025-09-17 14:59:24,129 - TopMost - Epoch: 200 loss: 1396.122
# 100%|██████████| 200/200 [00:59<00:00,  3.36it/s]
# Topic 0: minister prime north said korea nuclear putin south parliament country international government korean missile power
# Topic 1: sanders mrs say said mueller bernie schmidt name musk never declined changed personal change comment
# Topic 2: new said city data public country social based year online system already million announced plans
# Topic 3: far even south risk india right side though less likely found majority significant many especially
# Topic 4: deal legislation push efforts pressure pushed amazon promised proposal effort sweeping fight agreed regulators backed
# Topic 5: israel israeli france paris blasio jerusalem jewish citizens palestinians group spanish arab gaza palestinian spain
# Topic 6: company companies power use technology say industry google largest using electric emissions internet cars businesses
# Topic 7: archived barbaro won history win victory events sept opioid distancing defeat winning presidency odds wikileaks
# Topic 8: new york last according year said month week reported months since earlier tuesday latest taken
# Topic 9: days day weeks two hours next saturday sunday night second early june morning march taking
# Topic 10: case charges sexual investigation former allegations attorney accused criminal prosecutors trial court guilty lawyers prison
# Topic 11: two family government british private gun prince foreign london close son account money crime authorities
# Topic 12: law court federal rights justice rules decision legal supreme case judge act order laws ban
# Topic 13: president obama climate policy speaking strategy race reporters journalists vice advisers actions panel policies focused
# Topic 14: billion percent market financial inflation money growth companies prices million economy economic investors jobs costs
# Topic 15: said recording also country told statement made saying added clear described found including reporting adding
# Topic 16: just like really something think know one much things life way going thing get little
# Topic 17: governor black local district mayor cuomo long county gov community california residents communities democratic rural
# Topic 18: first team show two game league video players season years year games director series major
# Topic 19: public white speech protests government violence movement leader leaders raised mark face protest first response
# Topic 20: health said cases care johnson patients disease drug medical vaccinated deaths experts number vaccination need
# Topic 21: women hong many without kong even public men restrictions two open question access free say
# Topic 22: percent home workers now still one another point hospital lost left third likely run primary
# Topic 23: michael going just know right think get want back really see come time good got
# Topic 24: china european chinese union countries trade sanctions leaders meeting beijing germany leader fully meet communist
# Topic 25: military forces war saudi killed attack security afghanistan said troops iran taliban government officials syria
# Topic 26: first years time known made called including took two later used year last like came
# Topic 27: school students high schools young areas college number parents families across work low whose cities
# Topic 28: states united american americans program nations officials countries iran effort canada sought provide authorized washington
# Topic 29: trump russian russia ukraine donald ukrainian border moscow vladimir richard real relations human show controlled
# Topic 30: house administration white government office security federal voting agency congress secretary service staff employees announced
# Topic 31: state pandemic university texas department became outbreak organization california institute education reopen civil science association
# Topic 32: coronavirus virus test variant testing results masks tests mask tested symptoms drugs false language immune
# Topic 33: jan feb nov omicron uber suleimani fauci oct kyiv calif khashoggi boko markle lockdowns mnuchin
# Topic 34: world change led crisis europe decades part since years recent end summer decade concerns middle
# Topic 35: chief executive general representative former longtime chairman resigned vice director republican resignation senior deputy leadership
# Topic 36: city new past air york island hit miles immigration florida million storm sea rising cities
# Topic 37: children live died death child wife professor lives mother person family daughter born university poor
# Topic 38: said news media says wrote interview calls called call asked network james director weinstein press
# Topic 39: vaccine vaccines doses pfizer tesla deliver trials goal astrazeneca billion booster athletes buttigieg jump delivery
# Topic 40: now members group help move way control keep member britain business become take travel money
# Topic 41: officials national washington former monday week top wednesday thursday house friday capitol news tuesday calling
# Topic 42: report department official intelligence investigation information committee whether inquiry app fbi questions apple involved documents
# Topic 43: political campaign party support democratic presidential candidates politics conservative debate candidate election raising abortion supporters
# Topic 44: police killed man officers fire shot street car officer scene shooting back killing one people
# Topic 45: tax plan oil gas bill energy measure food proposed income set housing budget house economic
# Topic 46: election republican democrats vote republicans senate voters senator clinton congress lawmakers bill impeachment voted elections
# Topic 47: people one like times many day time making includes cover even least start small daily
# Topic 48: also including thousands around across since along city image hundreds millions two near people several
# Topic 49: president biden facebook twitter joe credit page elizabeth robert joseph cohen scott ashley harry instagram

# %%
"""
测试集主题模型推理并保存结果到CSV文件

"""

import pandas as pd
import numpy as np
import torch
import os
from typing import List, Tuple, Union
os.chdir("C:/Users/1/Desktop/TopMost")

# preprocess = Preprocess()
# new_bow=preprocess.parse(dataset.test, vocab=dataset.vocab)
# trainer.test(torch.as_tensor(new_bow.toarray(), device=device).float())

testtheta=trainer.test(torch.as_tensor(dataset.test_bow, device=device).float())
# testresults[1]
test_texts_dir = dataset_dir+"/test_texts.txt"

output_dir="C:/Users/1/Desktop/TopMost/LCLLMTM/NTM_results"
topic_ids= testtheta.argmax(1) 
# print(topic_ids)

# 1. 读取测试文本
print("正在读取测试文本...")
with open(test_texts_dir, 'r', encoding='utf-8') as f:
    test_texts = [line.strip() for line in f.readlines()]

# 3. 生成主题词列表
topic_words_list = []
for topic_id in topic_ids:
    topic_words_list.append(top_words[topic_id])

# 4. 创建DataFrame
data = {
    'ID': range(1, len(test_texts) + 1),  # 从1开始的序号
    'text': test_texts,
    'topic ID': topic_ids,
    'topic word list': topic_words_list
}

df = pd.DataFrame(data)

# 5. 创建输出目录并保存
os.makedirs(output_dir, exist_ok=True)
output_path = os.path.join(output_dir, dataset_name+"_"+method+"_testdata_inferred.csv")

df.to_csv(output_path, index=False, encoding='utf-8-sig')

print(f"✅ CSV文件已生成: {output_path}")
print(f"📊 处理了 {len(test_texts)} 条文本，发现 {len(set(topic_ids))} 个主题")


# len(testtheta)
# Out:
# 正在读取测试文本...
# ✅ CSV文件已生成: C:/Users/1/Desktop/TopMost/LCLLMTM/NTM_results\NYT_ETM_testdata_inferred.csv
# 📊 处理了 918 条文本，发现 48 个主题

# %%
os.chdir("C:/Users/1/Desktop/TopMost/LCLLMTM/topic_evaluation")
from topic_eval_combine import TopicEvaluationRunner

topwords_list=[i.split(" ") for i in top_words]
texts_path=output_path
# texts_path="C:/Users/1/Desktop/TopMost/LCLLMTM/data4LCLLM/NYT_Dataset.csv"
api_key='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'
model="qwen/qwen3-235b-a22b:free"
output_file=os.path.join(output_dir,dataset_name+"_"+method+"_topics_eval.json")


config = {
    'texts_path': texts_path,
    'topics_path': "C:/Users/1/Desktop/TopMost/LCLLMTM/LLM_response_results/topic_analysis_NYT_sampled_deepseek_deepseek_chat_v3.1.json",  # 直接提供关键词列表
    'api_key': api_key,
    'model': model,
    'output_file': output_file,
}

runner = TopicEvaluationRunner(config)

# # Run metric evaluation and print results
results = runner.run_metric_evaluation()
runner.print_results(results)

# Run LLM evaluation
_ = runner.run_llm_evaluation()
# Out:
# Successfully loaded CSV with utf-8 encoding
# topic_diversity: 0.9040
# npmi_coherence_window: 0.4600
# === LLM主题评估开始 ===
# 使用模型: qwen/qwen3-235b-a22b:free
# 待评估主题数量: 50
# API密钥已设置: sk-or-v1-960451...a37fb0335a3c
#
# 正在评估主题 1/50...
# 主题 1: ['Iran', 'Politics and Government', 'Ahmadinejad', 'Khamenei', 'Nuclear Weapons', 'Embargoes', 'International Relations']
# 🤖 正在调用LLM评估主题 1 (尝试 1/3)...
#    关键词: Iran, Politics and Government, Ahmadinejad, Khamenei, Nuclear Weapons...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 1 评估完成 - coherence: 5, conciseness: 4, informativity: 5
#
# 正在评估主题 2/50...
# 主题 2: ['China', 'Politics and Government', 'Human Rights', 'Censorship', 'International Relations', 'United States', 'Xi Jinping']
# 🤖 正在调用LLM评估主题 2 (尝试 1/3)...
#    关键词: China, Politics and Government, Human Rights, Censorship, International Relations...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 2 评估完成 - coherence: 3, conciseness: 3, informativity: 4
#
# 正在评估主题 3/50...
# 主题 3: ['Iraq', 'Iraq War', 'Defense and Military Forces', 'Terrorism', 'Maliki', 'Politics and Government', 'Civilian Casualties']
# 🤖 正在调用LLM评估主题 3 (尝试 1/3)...
#    关键词: Iraq, Iraq War, Defense and Military Forces, Terrorism, Maliki...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 3 评估完成 - coherence: 4, conciseness: 3, informativity: 4
#
# 正在评估主题 4/50...
# 主题 4: ['Demonstrations and Riots', 'Politics and Government', 'Elections', 'Protests', 'Civil Unrest', 'Freedom and Human Rights']
# 🤖 正在调用LLM评估主题 4 (尝试 1/3)...
#    关键词: Demonstrations and Riots, Politics and Government, Elections, Protests, Civil Unrest...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 4 评估完成 - coherence: 4, conciseness: 3, informativity: 3
#
# 正在评估主题 5/50...
# 主题 5: ['North Korea', 'Nuclear Weapons', 'International Relations', 'South Korea', 'Disarmament', 'Embargoes', 'China']
# 🤖 正在调用LLM评估主题 5 (尝试 1/3)...
#    关键词: North Korea, Nuclear Weapons, International Relations, South Korea, Disarmament...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 5 评估完成 - coherence: 5, conciseness: 5, informativity: 5
#
# 正在评估主题 6/50...
# 主题 6: ['Israel', 'Palestinians', 'Gaza Strip', 'Defense and Military Forces', 'Hamas', 'Hezbollah', 'Civilian Casualties']
# 🤖 正在调用LLM评估主题 6 (尝试 1/3)...
#    关键词: Israel, Palestinians, Gaza Strip, Defense and Military Forces, Hamas...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 6 评估完成 - coherence: 4, conciseness: 3, informativity: 4
#
# 正在评估主题 7/50...
# 主题 7: ['Afghanistan', 'United States Defense and Military Forces', 'Taliban', 'Terrorism', 'Karzai', 'International Relations', 'War']
# 🤖 正在调用LLM评估主题 7 (尝试 1/3)...
#    关键词: Afghanistan, United States Defense and Military Forces, Taliban, Terrorism, Karzai...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 7 评估完成 - coherence: 4, conciseness: 3, informativity: 4
#
# 正在评估主题 8/50...
# 主题 8: ['Russia', 'Putin', 'Medvedev', 'Politics and Government', 'Elections', 'Espionage', 'International Relations']
# 🤖 正在调用LLM评估主题 8 (尝试 1/3)...
#    关键词: Russia, Putin, Medvedev, Politics and Government, Elections...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 8 评估完成 - coherence: 4, conciseness: 3, informativity: 3
#
# 正在评估主题 9/50...
# 主题 9: ['Terrorism', 'Al Qaeda', 'Pakistan', 'Taliban', 'United States Defense and Military Forces', 'Counterterrorism', 'Militants']
# 🤖 正在调用LLM评估主题 9 (尝试 1/3)...
#    关键词: Terrorism, Al Qaeda, Pakistan, Taliban, United States Defense and Military Forces...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 9 评估完成 - coherence: 5, conciseness: 5, informativity: 5
#
# 正在评估主题 10/50...
# 主题 10: ['European Union', 'Economic Conditions', 'Greece', 'Germany', 'Debt Crisis', 'Austerity', 'Politics']
# 🤖 正在调用LLM评估主题 10 (尝试 1/3)...
#    关键词: European Union, Economic Conditions, Greece, Germany, Debt Crisis...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 10 评估完成 - coherence: 4, conciseness: 4, informativity: 4
#
# 正在评估主题 11/50...
# 主题 11: ['Climate Change', 'Global Warming', 'Environment', 'Disasters', 'Greenhouse Gas Emissions', 'Natural Disasters']
# 🤖 正在调用LLM评估主题 11 (尝试 1/3)...
#    关键词: Climate Change, Global Warming, Environment, Disasters, Greenhouse Gas Emissions...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 11 评估完成 - coherence: 4, conciseness: 3, informativity: 5
#
# 正在评估主题 12/50...
# 主题 12: ['Latin America', 'Drug Trafficking', 'Mexico', 'Colombia', 'United States International Relations', 'Venezuela', 'Politics']
# 🤖 正在调用LLM评估主题 12 (尝试 1/3)...
#    关键词: Latin America, Drug Trafficking, Mexico, Colombia, United States International Relations...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 12 评估完成 - coherence: 4, conciseness: 3, informativity: 3
#
# 正在评估主题 13/50...
# 主题 13: ['Africa', 'Economic Conditions', 'Politics and Government', 'Conflict', 'Foreign Aid', 'Poverty', 'Leadership']
# 🤖 正在调用LLM评估主题 13 (尝试 1/3)...
#    关键词: Africa, Economic Conditions, Politics and Government, Conflict, Foreign Aid...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 13 评估完成 - coherence: 4, conciseness: 5, informativity: 3
#
# 正在评估主题 14/50...
# 主题 14: ['Human Rights', 'Torture', 'Detainees', 'Prisons', 'Interrogations', 'CIA', 'Abuses']
# 🤖 正在调用LLM评估主题 14 (尝试 1/3)...
#    关键词: Human Rights, Torture, Detainees, Prisons, Interrogations...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 14 评估完成 - coherence: 4, conciseness: 3, informativity: 4
#
# 正在评估主题 15/50...
# 主题 15: ['Sanctions', 'Embargoes', 'International Relations', 'Iran', 'North Korea', 'Russia', 'Economic Impact']
# 🤖 正在调用LLM评估主题 15 (尝试 1/3)...
#    关键词: Sanctions, Embargoes, International Relations, Iran, North Korea...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 15 评估完成 - coherence: 4, conciseness: 5, informativity: 4
#
# 正在评估主题 16/50...
# 主题 16: ['Refugees', 'Migration', 'Humanitarian Crisis', 'Displacement', 'Asylum', 'Border Conflicts', 'International Aid']
# 🤖 正在调用LLM评估主题 16 (尝试 1/3)...
#    关键词: Refugees, Migration, Humanitarian Crisis, Displacement, Asylum...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 16 评估完成 - coherence: 5, conciseness: 5, informativity: 5
#
# 正在评估主题 17/50...
# 主题 17: ['Natural Gas', 'Energy', 'Russia', 'Ukraine', 'Pipeline Disputes', 'Economic Dependence', 'Gazprom']
# 🤖 正在调用LLM评估主题 17 (尝试 1/3)...
#    关键词: Natural Gas, Energy, Russia, Ukraine, Pipeline Disputes...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 17 评估完成 - coherence: 4, conciseness: 3, informativity: 4
#
# 正在评估主题 18/50...
# 主题 18: ['Elections', 'Voting', 'Democracy', 'Political Transitions', 'Election Fraud', 'International Observers', 'Power Transfers']
# 🤖 正在调用LLM评估主题 18 (尝试 1/3)...
#    关键词: Elections, Voting, Democracy, Political Transitions, Election Fraud...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 18 评估完成 - coherence: 5, conciseness: 4, informativity: 5
#
# 正在评估主题 19/50...
# 主题 19: ['Missiles', 'Space Programs', 'Military Technology', 'Defense Systems', 'Nuclear Capability', 'Satellites', 'Arms Race']
# 🤖 正在调用LLM评估主题 19 (尝试 1/3)...
#    关键词: Missiles, Space Programs, Military Technology, Defense Systems, Nuclear Capability...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 19 评估完成 - coherence: 4, conciseness: 5, informativity: 4
#
# 正在评估主题 20/50...
# 主题 20: ['Corruption', 'Political Scandals', 'Accountability', 'Bribery', 'Ethics', 'Investigations', 'Governance']
# 🤖 正在调用LLM评估主题 20 (尝试 1/3)...
#    关键词: Corruption, Political Scandals, Accountability, Bribery, Ethics...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 20 评估完成 - coherence: 5, conciseness: 5, informativity: 5
#
# 正在评估主题 21/50...
# 主题 21: ['Pandemics', 'Disease Outbreaks', 'Public Health', 'Epidemics', 'Vaccines', 'WHO', 'Health Crises']
# 🤖 正在调用LLM评估主题 21 (尝试 1/3)...
#    关键词: Pandemics, Disease Outbreaks, Public Health, Epidemics, Vaccines...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 21 评估完成 - coherence: 5, conciseness: 4, informativity: 4
#
# 正在评估主题 22/50...
# 主题 22: ['Cyber Warfare', 'Espionage', 'Internet Freedom', 'Digital Security', 'Hacking', 'Surveillance', 'Wikileaks']
# 🤖 正在调用LLM评估主题 22 (尝试 1/3)...
#    关键词: Cyber Warfare, Espionage, Internet Freedom, Digital Security, Hacking...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 22 评估完成 - coherence: 4, conciseness: 5, informativity: 4
#
# 正在评估主题 23/50...
# 主题 23: ['Religious Extremism', 'Terrorism', 'Radicalization', 'Security Threats', 'Fundamentalism', 'Counter-extremism', 'Social Impact']
# 🤖 正在调用LLM评估主题 23 (尝试 1/3)...
#    关键词: Religious Extremism, Terrorism, Radicalization, Security Threats, Fundamentalism...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 23 评估完成 - coherence: 4, conciseness: 5, informativity: 4
#
# 正在评估主题 24/50...
# 主题 24: ['Maritime Security', 'Piracy', 'Naval Operations', 'Shipping Lanes', 'International Waters', 'Coastal Defense', 'Sea Power']
# 🤖 正在调用LLM评估主题 24 (尝试 1/3)...
#    关键词: Maritime Security, Piracy, Naval Operations, Shipping Lanes, International Waters...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 24 评估完成 - coherence: 5, conciseness: 5, informativity: 4
#
# 正在评估主题 25/50...
# 主题 25: ['Cultural Heritage', 'Historic Preservation', 'Conflict Zones', 'Archaeology', 'Destruction of Heritage', 'Cultural Sites', 'Restoration']
# 🤖 正在调用LLM评估主题 25 (尝试 1/3)...
#    关键词: Cultural Heritage, Historic Preservation, Conflict Zones, Archaeology, Destruction of Heritage...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 25 评估完成 - coherence: 5, conciseness: 4, informativity: 5
#
# 正在评估主题 26/50...
# 主题 26: ['Labor Rights', "Workers' Movements", 'Economic Justice', 'Strikes', 'Wages', 'Working Conditions', 'Unionization']
# 🤖 正在调用LLM评估主题 26 (尝试 1/3)...
#    关键词: Labor Rights, Workers' Movements, Economic Justice, Strikes, Wages...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 26 评估完成 - coherence: 5, conciseness: 5, informativity: 5
#
# 正在评估主题 27/50...
# 主题 27: ['Food Security', 'Agriculture', 'Hunger Crises', 'Famine', 'Agricultural Policy', 'Food Prices', 'Nutrition']
# 🤖 正在调用LLM评估主题 27 (尝试 1/3)...
#    关键词: Food Security, Agriculture, Hunger Crises, Famine, Agricultural Policy...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 27 评估完成 - coherence: 5, conciseness: 5, informativity: 5
#
# 正在评估主题 28/50...
# 主题 28: ['Wildlife Conservation', 'Poaching', 'Environmental Protection', 'Endangered Species', 'Animal Rights', 'Habitat Preservation', 'Biodiversity']
# 🤖 正在调用LLM评估主题 28 (尝试 1/3)...
#    关键词: Wildlife Conservation, Poaching, Environmental Protection, Endangered Species, Animal Rights...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 28 评估完成 - coherence: 5, conciseness: 4, informativity: 4
#
# 正在评估主题 29/50...
# 主题 29: ['Disaster Response', 'Emergency Management', 'Natural Disasters', 'Relief Efforts', 'Recovery Operations', 'Humanitarian Aid', 'Crisis Response']
# 🤖 正在调用LLM评估主题 29 (尝试 1/3)...
#    关键词: Disaster Response, Emergency Management, Natural Disasters, Relief Efforts, Recovery Operations...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 29 评估完成 - coherence: 5, conciseness: 4, informativity: 5
#
# 正在评估主题 30/50...
# 主题 30: ['Technological Innovation', 'Digital Transformation', 'Society Impact', 'Advanced Technology', 'Innovation Policy', 'Tech Development', 'Future Trends']
# 🤖 正在调用LLM评估主题 30 (尝试 1/3)...
#    关键词: Technological Innovation, Digital Transformation, Society Impact, Advanced Technology, Innovation Policy...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 30 评估完成 - coherence: 4, conciseness: 3, informativity: 3
#
# 正在评估主题 31/50...
# 主题 31: ['War Crimes', 'International Justice', 'ICC', 'Accountability', 'Genocide', 'Human Rights Violations', 'Tribunals']
# 🤖 正在调用LLM评估主题 31 (尝试 1/3)...
#    关键词: War Crimes, International Justice, ICC, Accountability, Genocide...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 31 评估完成 - coherence: 5, conciseness: 4, informativity: 5
#
# 正在评估主题 32/50...
# 主题 32: ['Urban Development', 'Infrastructure', 'City Planning', 'Urbanization', 'Construction', 'Public Works', 'Metropolitan Growth']
# 🤖 正在调用LLM评估主题 32 (尝试 1/3)...
#    关键词: Urban Development, Infrastructure, City Planning, Urbanization, Construction...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 32 评估完成 - coherence: 5, conciseness: 4, informativity: 4
#
# 正在评估主题 33/50...
# 主题 33: ['Education Systems', 'Educational Reform', 'Access to Education', 'Literacy', 'Schooling', 'Educational Policy', 'Learning Outcomes']
# 🤖 正在调用LLM评估主题 33 (尝试 1/3)...
#    关键词: Education Systems, Educational Reform, Access to Education, Literacy, Schooling...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 33 评估完成 - coherence: 4, conciseness: 5, informativity: 5
#
# 正在评估主题 34/50...
# 主题 34: ['Space Exploration', 'Astronomy', 'NASA', 'Space Agencies', 'Planetary Science', 'Space Missions', 'International Cooperation']
# 🤖 正在调用LLM评估主题 34 (尝试 1/3)...
#    关键词: Space Exploration, Astronomy, NASA, Space Agencies, Planetary Science...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 34 评估完成 - coherence: 4, conciseness: 5, informativity: 4
#
# 正在评估主题 35/50...
# 主题 35: ['Indigenous Rights', 'Cultural Preservation', 'Native Communities', 'Land Rights', 'Traditional Knowledge', 'Self-determination', 'Cultural Heritage']
# 🤖 正在调用LLM评估主题 35 (尝试 1/3)...
#    关键词: Indigenous Rights, Cultural Preservation, Native Communities, Land Rights, Traditional Knowledge...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 35 评估完成 - coherence: 5, conciseness: 5, informativity: 5
#
# 正在评估主题 36/50...
# 主题 36: ['Financial Markets', 'Economic Policy', 'Global Trade', 'Investment', 'Market Regulation', 'Trade Relations', 'Economic Development']
# 🤖 正在调用LLM评估主题 36 (尝试 1/3)...
#    关键词: Financial Markets, Economic Policy, Global Trade, Investment, Market Regulation...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 36 评估完成 - coherence: 4, conciseness: 4, informativity: 3
#
# 正在评估主题 37/50...
# 主题 37: ['Water Management', 'Conservation', 'Water Scarcity', 'Hydrology', 'Water Policy', 'Freshwater Resources', 'Sustainable Use']
# 🤖 正在调用LLM评估主题 37 (尝试 1/3)...
#    关键词: Water Management, Conservation, Water Scarcity, Hydrology, Water Policy...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 37 评估完成 - coherence: 5, conciseness: 4, informativity: 5
#
# 正在评估主题 38/50...
# 主题 38: ['Media Freedom', 'Journalism Safety', 'Information Access', 'Press Rights', 'Censorship', 'News Media', 'Information Control']
# 🤖 正在调用LLM评估主题 38 (尝试 1/3)...
#    关键词: Media Freedom, Journalism Safety, Information Access, Press Rights, Censorship...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 38 评估完成 - coherence: 5, conciseness: 4, informativity: 4
#
# 正在评估主题 39/50...
# 主题 39: ['Arctic Exploration', 'Polar Regions', 'Climate Change', 'Ice Melting', 'Polar Research', 'Arctic Policy', 'Environmental Changes']
# 🤖 正在调用LLM评估主题 39 (尝试 1/3)...
#    关键词: Arctic Exploration, Polar Regions, Climate Change, Ice Melting, Polar Research...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 39 评估完成 - coherence: 4, conciseness: 5, informativity: 3
#
# 正在评估主题 40/50...
# 主题 40: ['Sports Diplomacy', 'International Sports', 'Olympics', 'World Cup', 'Athletic Competition', 'Sports Politics', 'Global Sports']
# 🤖 正在调用LLM评估主题 40 (尝试 1/3)...
#    关键词: Sports Diplomacy, International Sports, Olympics, World Cup, Athletic Competition...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 40 评估完成 - coherence: 5, conciseness: 3, informativity: 4
#
# 正在评估主题 41/50...
# 主题 41: ['Artificial Intelligence', 'Ethics', 'Regulation', 'Machine Learning', 'AI Policy', 'Technology Ethics', 'Automation']
# 🤖 正在调用LLM评估主题 41 (尝试 1/3)...
#    关键词: Artificial Intelligence, Ethics, Regulation, Machine Learning, AI Policy...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 41 评估完成 - coherence: 4, conciseness: 3, informativity: 3
#
# 正在评估主题 42/50...
# 主题 42: ['Renewable Energy', 'Sustainability', 'Green Technology', 'Clean Energy', 'Environmental Policy', 'Energy Transition', 'Sustainable Development']
# 🤖 正在调用LLM评估主题 42 (尝试 1/3)...
#    关键词: Renewable Energy, Sustainability, Green Technology, Clean Energy, Environmental Policy...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 42 评估完成 - coherence: 4, conciseness: 3, informativity: 4
#
# 正在评估主题 43/50...
# 主题 43: ['Mental Health', 'Healthcare Access', 'Psychological Services', 'Mental Wellness', 'Treatment Options', 'Healthcare Systems', 'Wellbeing']
# 🤖 正在调用LLM评估主题 43 (尝试 1/3)...
#    关键词: Mental Health, Healthcare Access, Psychological Services, Mental Wellness, Treatment Options...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 43 评估完成 - coherence: 4, conciseness: 4, informativity: 4
#
# 正在评估主题 44/50...
# 主题 44: ['Cryptocurrency', 'Digital Currency', 'Blockchain', 'Financial Technology', 'Currency Policy', 'Digital Assets', 'Monetary Systems']
# 🤖 正在调用LLM评估主题 44 (尝试 1/3)...
#    关键词: Cryptocurrency, Digital Currency, Blockchain, Financial Technology, Currency Policy...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 44 评估完成 - coherence: 4, conciseness: 5, informativity: 5
#
# 正在评估主题 45/50...
# 主题 45: ['Ocean Conservation', 'Marine Ecosystems', 'Ocean Policy', 'Marine Protection', 'Sea Conservation', 'Ocean Health', 'Marine Biodiversity']
# 🤖 正在调用LLM评估主题 45 (尝试 1/3)...
#    关键词: Ocean Conservation, Marine Ecosystems, Ocean Policy, Marine Protection, Sea Conservation...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 45 评估完成 - coherence: 5, conciseness: 3, informativity: 4
#
# 正在评估主题 46/50...
# 主题 46: ['Aging Population', 'Elder Care', 'Demographic Change', 'Senior Services', 'Population Aging', 'Elderly Support', 'Geriatric Care']
# 🤖 正在调用LLM评估主题 46 (尝试 1/3)...
#    关键词: Aging Population, Elder Care, Demographic Change, Senior Services, Population Aging...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 46 评估完成 - coherence: 5, conciseness: 3, informativity: 4
#
# 正在评估主题 47/50...
# 主题 47: ['Digital Privacy', 'Data Protection', 'Privacy Rights', 'Information Security', 'Data Regulation', 'Privacy Laws', 'Digital Rights']
# 🤖 正在调用LLM评估主题 47 (尝试 1/3)...
#    关键词: Digital Privacy, Data Protection, Privacy Rights, Information Security, Data Regulation...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 47 评估完成 - coherence: 5, conciseness: 4, informativity: 5
#
# 正在评估主题 48/50...
# 主题 48: ['Urban Transportation', 'Mobility Solutions', 'Transit Systems', 'City Mobility', 'Transportation Planning', 'Urban Mobility', 'Public Transit']
# 🤖 正在调用LLM评估主题 48 (尝试 1/3)...
#    关键词: Urban Transportation, Mobility Solutions, Transit Systems, City Mobility, Transportation Planning...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 48 评估完成 - coherence: 5, conciseness: 3, informativity: 4
#
# 正在评估主题 49/50...
# 主题 49: ['Gender Equality', "Women's Empowerment", 'Gender Policy', 'Equal Rights', "Women's Rights", 'Gender Initiatives', 'Empowerment Programs']
# 🤖 正在调用LLM评估主题 49 (尝试 1/3)...
#    关键词: Gender Equality, Women's Empowerment, Gender Policy, Equal Rights, Women's Rights...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 49 评估完成 - coherence: 5, conciseness: 3, informativity: 4
#
# 正在评估主题 50/50...
# 主题 50: ['Sustainable Agriculture', 'Food Production', 'Agricultural Innovation', 'Farming Practices', 'Food Sustainability', 'Agricultural Technology', 'Sustainable Farming']
# 🤖 正在调用LLM评估主题 50 (尝试 1/3)...
#    关键词: Sustainable Agriculture, Food Production, Agricultural Innovation, Farming Practices, Food Sustainability...
# ✅ LLM响应已接收，正在解析结果...
# 📊 主题 50 评估完成 - coherence: 4, conciseness: 3, informativity: 4
#
# 评估结果已保存到: C:/Users/1/Desktop/TopMost/LCLLMTM/NTM_results\NYT_ETM_topics_eval.json
#
# ================================================================================
# 📊 LLM主题评估报告
# ================================================================================
#
# 🔧 评估配置:
#    模型: qwen/qwen3-235b-a22b:free
#    评估时间: 2025-09-17 18:42:16
#    总主题数: 50
#
# 📈 评估统计:
#    成功评估: 50
#    失败评估: 0
#
# 📊 各维度平均分:
#
# 💡 评估建议:
#    - 主题质量较差，建议重新生成或大幅优化

# %%
# ########################### test new documents ####################################
# import torch
# from topmost import Preprocess

# preprocess = Preprocess()

# new_docs = [
#     "This is a new document about space, including words like space, satellite, launch, orbit.",
#     "This is a new document about Microsoft Windows, including words like windows, files, dos."
# ]

# parsed_new_docs, new_bow = preprocess.parse(new_docs, vocab=dataset.vocab)
# new_theta = trainer.test(torch.as_tensor(new_bow.toarray(), device=device).float())

# print(new_theta.argmax(1))
# Out:
# parsing texts: 100%|██████████| 2/2 [00:00<00:00, 4088.02it/s]
# [44 10]
# /etc/miniconda3/envs/topmost2/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
